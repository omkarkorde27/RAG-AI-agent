# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "Indiana University Bloomington was founded in the year 1818. It is a public research based university.",
    metadata = {
        "source": "Indiana.txt",
        "pages": 5,
        "timestamp": "2025-09-12",
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'Indiana.txt', 'pages': 5, 'timestamp': '2025-09-12'}, page_content='Indiana University Bloomington was founded in the year 1818. It is a public research based university.')

# %%
import os

os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt": """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems"""
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("sample text files created!")
# Out:
# sample text files created!

# %%
from langchain.document_loaders import TextLoader

loader=TextLoader("/Users/User/Documents/RAG AI agent/data/text_files/machine_learning.txt", encoding="utf-8")

document=loader.load()

print(document)
# Out:
# [Document(metadata={'source': '/Users/User/Documents/RAG AI agent/data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems')]

# %%
from langchain_community.document_loaders import DirectoryLoader
import tqdm

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # Pattern to match files
    loader_cls=TextLoader, # loader class to use
    loader_kwargs={"encoding":"utf-8"},
    show_progress=True
)

documents=dir_loader.load()
print(documents)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 2380.42it/s]
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'), Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    # loader_kwargs={"encoding":"utf-8"},
    show_progress=True
)

pdf_documents=dir_loader.load()
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 35.19it/s]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
# Text splitting get into chunks

def split_documents(documents, chunk_size=1000, chunk_overlap=200):
    """Split documents into smaller size for better RAG performance"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap,
        length_function = len,
        separators = ["\n\n", "\n", " ", ""]
    )
    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents in {len(split_docs)} chunks")

    if split_docs:
        print(f"\nExample Chunk: ")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")

    return split_docs

# %%
chunks=split_documents(pdf_documents)
# Out:
# Split 85 documents in 248 chunks
#
# Example Chunk:
# Content: MoF Policy 007: Officer Recusal Rules
# Effective: 2024-07-01​
#  Owner: Ministry of Flowgramming (MoF)​
#  Category: Ordinance IV — Conflicts of Interest & Human-in-the-Loop
# 1. Mandatory Recusal Categori...
# Metadata: {'producer': 'Skia/PDF m141 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/MoF-policy-07.pdf', 'file_path': '../data/pdf/MoF-policy-07.pdf', 'total_pages': 7, 'format': 'PDF 1.4', 'title': 'MoF-policy-07', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}

# %% [markdown]
# # Embedding and VectoreStoreDB

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Dict, Tuple, Any
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /Users/User/Documents/RAG-AI-agent-clean/.venv/lib/python3.13/site-packages/chromadb/execution/expression/operator.py:239: SyntaxWarning: invalid escape sequence '\.'
#   Key("email").regex(r".*@example\.com")

# %%
class EmbeddingManager:
    """Handles documents embedding generation with the help of SentenceTransformer"""

    def __init__(self, model_name: str="all-MiniLM-L6-v2"):
        """
        Initiliaze the Embedding Manager
        
        Args:
            model_name: HuggingFace model name for embeddings
        """
        self.model_name= model_name
        self.model=None
        self._load_model()

    def _load_model(self):
        """Load the SentenceTransformer model"""

        try:
            print(f"Load embedding model: {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model loaded successfully. Embedding dimension {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"Error loading model {self.model_name}: {e}")
            raise

    def generate_embeddings(self, texts:List[str]) -> np.ndarray:
        """
        Generate embedings for a list of texts

        Args:
            List of text strings to embed

        Returns:
            numpy array of embeddings with shape len(texts), embedding_dim)
        """

        if not self.model:
            raise ValueError("Model not loaded")
        
        print(f"Generate embeddings for {len(texts)} texts...")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print("Generated embeddings with shape: {embeddings.shape}")
        return embeddings
    

embedding_manager = EmbeddingManager()
embedding_manager
# Out:
# Load embedding model: all-MiniLM-L6-v2
# Model loaded successfully. Embedding dimension 384

# %% [markdown]
# # VectoreStore

# %%
class VectorStore:
    """ Manages document embeddings in a ChromaDB vector store"""
    def __init__(self, collection_name: str="pdf_documents", persist_directory: str = "../data/vectore_store"):
        """
        Initialize the vector store
        
        Args:
            collection_name: Name of the ChromaDB collection
            persist_directory: Directory to persist the vector store
        """
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.client = None
        self.collection = None
        self.initialize_store()

    def initialize_store(self):
        """Initialize ChromaDB client and collection"""

        try:
            # Create chromaDB client and collection
            os.makedirs(self.persist_directory, exist_ok=True)
            self.client = chromadb.PersistentClient(path=self.persist_directory) # creates client that has a reference to the chromadb VectorStore using chromadb.PersistentClient fn

            # Get or create collection
            self.collection = self.client.get_or_create_collection(
                name=self.collection_name,
                metadata={"description": "PDF document embeddings for RAG"} # metadata contains what is the collection information
            )
            print(f"Collection store initialized. Collection: {self.collection_name}")
            print(f"Existing documents in collection: {self.collection.count()}")
        
        except Exception as e:
            print(f"Error initializing vector store: {e}")
            raise

    # Now that collection is created we need to insert documents into the collection
    # Fn to add list of documents to the collection
    def add_documents(self, documents: List[Any], embeddings: np.ndarray):
        """
        Add documents and their embeddings to the vectorstore

        Args:
            documents: List of Langchain documents
            embeddings: Corresponding embeddings to the documents
        """

        if len(documents) != len(embeddings):
            raise ValueError("Number of documents must match the number of embeddings")
        
        print(f"Add {len(documents)} documents to the vectorstore...")

        # Prepare data for ChromaDB(vectorstore)
        ids = []
        metadatas = []
        document_texts = []
        embeddings_list = []

        for i, (doc, embeddings) in enumerate(zip(documents, embeddings)): # documents zipped and created tuples with embeddings
            # Generate unique id
            doc_id = f"doc_{uuid.uuid4().hex[:8]}_{i}"
            ids.append(doc_id)

            # Prepare metadata
            metadata = dict(doc.metadata)
            metadata['doc_index'] = i
            metadata['content_length'] = len(doc.page_content)
            metadatas.append(metadata)
            
            # document content
            document_texts.append(doc.page_content)

            # embeddings 
            embeddings_list.append(embeddings.tolist())

            try:
                self.collection.add(
                    ids=ids,
                    embeddings=embeddings_list,
                    metadatas=metadatas,
                    documents=document_texts
                )
                print(f"Successfully added {len(documents)} documents to vectorestore")
                print(f"Total documents in collection: {self.collection.count()}")

            except Exception as e:
                print(f"Error loading documents in the vector store: {e}")
                raise 

vectorstore=VectorStore()
vectorstore
# Out:
# Collection store initialized. Collection: pdf_documents
# Existing documents in collection: 496

# %%
# chunks

# %%
### Convert the texts to embeddings

texts=[doc.page_content for doc in chunks]
# texts

# %%
embeddings=embedding_manager.generate_embeddings(texts)

vectorstore.add_documents(chunks, embeddings)
# Out:
# Generate embeddings for 248 texts...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches: 100%|██████████| 8/8 [00:02<00:00,  2.95it/s]
# Generated embeddings with shape: {embeddings.shape}
# Add 248 documents to the vectorstore...
# Successfully added 248 documents to vectorestore
# Total documents in collection: 497
# Successfully added 248 documents to vectorestore
# Total documents in collection: 498
# Successfully added 248 documents to vectorestore
# Total documents in collection: 499
# Successfully added 248 documents to vectorestore
# Total documents in collection: 500
# Successfully added 248 documents to vectorestore
# Total documents in collection: 501
# Successfully added 248 documents to vectorestore
# Total documents in collection: 502
# Successfully added 248 documents to vectorestore
# Total documents in collection: 503
# Successfully added 248 documents to vectorestore
# Total documents in collection: 504
# Successfully added 248 documents to vectorestore
# Total documents in collection: 505
# Successfully added 248 documents to vectorestore
# Total documents in collection: 506
# Successfully added 248 documents to vectorestore
# Total documents in collection: 507
# Successfully added 248 documents to vectorestore
# Total documents in collection: 508
# Successfully added 248 documents to vectorestore
# Total documents in collection: 509
# Successfully added 248 documents to vectorestore
# Total documents in collection: 510
# Successfully added 248 documents to vectorestore
# Total documents in collection: 511
# Successfully added 248 documents to vectorestore
# Total documents in collection: 512
# Successfully added 248 documents to vectorestore
# Total documents in collection: 513
# Successfully added 248 documents to vectorestore
# Total documents in collection: 514
# Successfully added 248 documents to vectorestore
# Total documents in collection: 515
# Successfully added 248 documents to vectorestore
# Total documents in collection: 516
# Successfully added 248 documents to vectorestore
# Total documents in collection: 517
# Successfully added 248 documents to vectorestore
# Total documents in collection: 518
# Successfully added 248 documents to vectorestore
# Total documents in collection: 519
# Successfully added 248 documents to vectorestore
# Total documents in collection: 520
# Successfully added 248 documents to vectorestore
# Total documents in collection: 521
# Successfully added 248 documents to vectorestore
# Total documents in collection: 522
# Successfully added 248 documents to vectorestore
# Total documents in collection: 523
# Successfully added 248 documents to vectorestore
# Total documents in collection: 524
# Successfully added 248 documents to vectorestore
# Total documents in collection: 525
# Successfully added 248 documents to vectorestore
# Total documents in collection: 526
# Successfully added 248 documents to vectorestore
# Total documents in collection: 527
# Successfully added 248 documents to vectorestore
# Total documents in collection: 528
# Successfully added 248 documents to vectorestore
# Total documents in collection: 529
# Successfully added 248 documents to vectorestore
# Total documents in collection: 530
# Successfully added 248 documents to vectorestore
# Total documents in collection: 531
# Successfully added 248 documents to vectorestore
# Total documents in collection: 532
# Successfully added 248 documents to vectorestore
# Total documents in collection: 533
# Successfully added 248 documents to vectorestore
# Total documents in collection: 534
# Successfully added 248 documents to vectorestore
# Total documents in collection: 535
# Successfully added 248 documents to vectorestore
# Total documents in collection: 536
# Successfully added 248 documents to vectorestore
# Total documents in collection: 537
# Successfully added 248 documents to vectorestore
# Total documents in collection: 538
# Successfully added 248 documents to vectorestore
# Total documents in collection: 539
# Successfully added 248 documents to vectorestore
# Total documents in collection: 540
# Successfully added 248 documents to vectorestore
# Total documents in collection: 541
# Successfully added 248 documents to vectorestore
# Total documents in collection: 542
# Successfully added 248 documents to vectorestore
# Total documents in collection: 543
# Successfully added 248 documents to vectorestore
# Total documents in collection: 544
# Successfully added 248 documents to vectorestore
# Total documents in collection: 545
# Successfully added 248 documents to vectorestore
# Total documents in collection: 546
# Successfully added 248 documents to vectorestore
# Total documents in collection: 547
# Successfully added 248 documents to vectorestore
# Total documents in collection: 548
# Successfully added 248 documents to vectorestore
# Total documents in collection: 549
# Successfully added 248 documents to vectorestore
# Total documents in collection: 550
# Successfully added 248 documents to vectorestore
# Total documents in collection: 551
# Successfully added 248 documents to vectorestore
# Total documents in collection: 552
# Successfully added 248 documents to vectorestore
# Total documents in collection: 553
# Successfully added 248 documents to vectorestore
# Total documents in collection: 554
# Successfully added 248 documents to vectorestore
# Total documents in collection: 555
# Successfully added 248 documents to vectorestore
# Total documents in collection: 556
# Successfully added 248 documents to vectorestore
# Total documents in collection: 557
# Successfully added 248 documents to vectorestore
# Total documents in collection: 558
# Successfully added 248 documents to vectorestore
# Total documents in collection: 559
# Successfully added 248 documents to vectorestore
# Total documents in collection: 560
# Successfully added 248 documents to vectorestore
# Total documents in collection: 561
# Successfully added 248 documents to vectorestore
# Total documents in collection: 562
# Successfully added 248 documents to vectorestore
# Total documents in collection: 563
# Successfully added 248 documents to vectorestore
# Total documents in collection: 564
# Successfully added 248 documents to vectorestore
# Total documents in collection: 565
# Successfully added 248 documents to vectorestore
# Total documents in collection: 566
# Successfully added 248 documents to vectorestore
# Total documents in collection: 567
# Successfully added 248 documents to vectorestore
# Total documents in collection: 568
# Successfully added 248 documents to vectorestore
# Total documents in collection: 569
# Successfully added 248 documents to vectorestore
# Total documents in collection: 570
# Successfully added 248 documents to vectorestore
# Total documents in collection: 571
# Successfully added 248 documents to vectorestore
# Total documents in collection: 572
# Successfully added 248 documents to vectorestore
# Total documents in collection: 573
# Successfully added 248 documents to vectorestore
# Total documents in collection: 574
# Successfully added 248 documents to vectorestore
# Total documents in collection: 575
# Successfully added 248 documents to vectorestore
# Total documents in collection: 576
# Successfully added 248 documents to vectorestore
# Total documents in collection: 577
# Successfully added 248 documents to vectorestore
# Total documents in collection: 578
# Successfully added 248 documents to vectorestore
# Total documents in collection: 579
# Successfully added 248 documents to vectorestore
# Total documents in collection: 580
# Successfully added 248 documents to vectorestore
# Total documents in collection: 581
# Successfully added 248 documents to vectorestore
# Total documents in collection: 582
# Successfully added 248 documents to vectorestore
# Total documents in collection: 583
# Successfully added 248 documents to vectorestore
# Total documents in collection: 584
# Successfully added 248 documents to vectorestore
# Total documents in collection: 585
# Successfully added 248 documents to vectorestore
# Total documents in collection: 586
# Successfully added 248 documents to vectorestore
# Total documents in collection: 587
# Successfully added 248 documents to vectorestore
# Total documents in collection: 588
# Successfully added 248 documents to vectorestore
# Total documents in collection: 589
# Successfully added 248 documents to vectorestore
# Total documents in collection: 590
# Successfully added 248 documents to vectorestore
# Total documents in collection: 591
# Successfully added 248 documents to vectorestore
# Total documents in collection: 592
# Successfully added 248 documents to vectorestore
# Total documents in collection: 593
# Successfully added 248 documents to vectorestore
# Total documents in collection: 594
# Successfully added 248 documents to vectorestore
# Total documents in collection: 595
# Successfully added 248 documents to vectorestore
# Total documents in collection: 596
# Successfully added 248 documents to vectorestore
# Total documents in collection: 597
# Successfully added 248 documents to vectorestore
# Total documents in collection: 598
# Successfully added 248 documents to vectorestore
# Total documents in collection: 599
# Successfully added 248 documents to vectorestore
# Total documents in collection: 600
# Successfully added 248 documents to vectorestore
# Total documents in collection: 601
# Successfully added 248 documents to vectorestore
# Total documents in collection: 602
# Successfully added 248 documents to vectorestore
# Total documents in collection: 603
# Successfully added 248 documents to vectorestore
# Total documents in collection: 604
# Successfully added 248 documents to vectorestore
# Total documents in collection: 605
# Successfully added 248 documents to vectorestore
# Total documents in collection: 606
# Successfully added 248 documents to vectorestore
# Total documents in collection: 607
# Successfully added 248 documents to vectorestore
# Total documents in collection: 608
# Successfully added 248 documents to vectorestore
# Total documents in collection: 609
# Successfully added 248 documents to vectorestore
# Total documents in collection: 610
# Successfully added 248 documents to vectorestore
# Total documents in collection: 611
# Successfully added 248 documents to vectorestore
# Total documents in collection: 612
# Successfully added 248 documents to vectorestore
# Total documents in collection: 613
# Successfully added 248 documents to vectorestore
# Total documents in collection: 614
# Successfully added 248 documents to vectorestore
# Total documents in collection: 615
# Successfully added 248 documents to vectorestore
# Total documents in collection: 616
# Successfully added 248 documents to vectorestore
# Total documents in collection: 617
# Successfully added 248 documents to vectorestore
# Total documents in collection: 618
# Successfully added 248 documents to vectorestore
# Total documents in collection: 619
# Successfully added 248 documents to vectorestore
# Total documents in collection: 620
# Successfully added 248 documents to vectorestore
# Total documents in collection: 621
# Successfully added 248 documents to vectorestore
# Total documents in collection: 622
# Successfully added 248 documents to vectorestore
# Total documents in collection: 623
# Successfully added 248 documents to vectorestore
# Total documents in collection: 624
# Successfully added 248 documents to vectorestore
# Total documents in collection: 625
# Successfully added 248 documents to vectorestore
# Total documents in collection: 626
# Successfully added 248 documents to vectorestore
# Total documents in collection: 627
# Successfully added 248 documents to vectorestore
# Total documents in collection: 628
# Successfully added 248 documents to vectorestore
# Total documents in collection: 629
# Successfully added 248 documents to vectorestore
# Total documents in collection: 630
# Successfully added 248 documents to vectorestore
# Total documents in collection: 631
# Successfully added 248 documents to vectorestore
# Total documents in collection: 632
# Successfully added 248 documents to vectorestore
# Total documents in collection: 633
# Successfully added 248 documents to vectorestore
# Total documents in collection: 634
# Successfully added 248 documents to vectorestore
# Total documents in collection: 635
# Successfully added 248 documents to vectorestore
# Total documents in collection: 636
# Successfully added 248 documents to vectorestore
# Total documents in collection: 637
# Successfully added 248 documents to vectorestore
# Total documents in collection: 638
# Successfully added 248 documents to vectorestore
# Total documents in collection: 639
# Successfully added 248 documents to vectorestore
# Total documents in collection: 640
# Successfully added 248 documents to vectorestore
# Total documents in collection: 641
# Successfully added 248 documents to vectorestore
# Total documents in collection: 642
# Successfully added 248 documents to vectorestore
# Total documents in collection: 643
# Successfully added 248 documents to vectorestore
# Total documents in collection: 644
# Successfully added 248 documents to vectorestore
# Total documents in collection: 645
# Successfully added 248 documents to vectorestore
# Total documents in collection: 646
# Successfully added 248 documents to vectorestore
# Total documents in collection: 647
# Successfully added 248 documents to vectorestore
# Total documents in collection: 648
# Successfully added 248 documents to vectorestore
# Total documents in collection: 649
# Successfully added 248 documents to vectorestore
# Total documents in collection: 650
# Successfully added 248 documents to vectorestore
# Total documents in collection: 651
# Successfully added 248 documents to vectorestore
# Total documents in collection: 652
# Successfully added 248 documents to vectorestore
# Total documents in collection: 653
# Successfully added 248 documents to vectorestore
# Total documents in collection: 654
# Successfully added 248 documents to vectorestore
# Total documents in collection: 655
# Successfully added 248 documents to vectorestore
# Total documents in collection: 656
# Successfully added 248 documents to vectorestore
# Total documents in collection: 657
# Successfully added 248 documents to vectorestore
# Total documents in collection: 658
# Successfully added 248 documents to vectorestore
# Total documents in collection: 659
# Successfully added 248 documents to vectorestore
# Total documents in collection: 660
# Successfully added 248 documents to vectorestore
# Total documents in collection: 661
# Successfully added 248 documents to vectorestore
# Total documents in collection: 662
# Successfully added 248 documents to vectorestore
# Total documents in collection: 663
# Successfully added 248 documents to vectorestore
# Total documents in collection: 664
# Successfully added 248 documents to vectorestore
# Total documents in collection: 665
# Successfully added 248 documents to vectorestore
# Total documents in collection: 666
# Successfully added 248 documents to vectorestore
# Total documents in collection: 667
# Successfully added 248 documents to vectorestore
# Total documents in collection: 668
# Successfully added 248 documents to vectorestore
# Total documents in collection: 669
# Successfully added 248 documents to vectorestore
# Total documents in collection: 670
# Successfully added 248 documents to vectorestore
# Total documents in collection: 671
# Successfully added 248 documents to vectorestore
# Total documents in collection: 672
# Successfully added 248 documents to vectorestore
# Total documents in collection: 673
# Successfully added 248 documents to vectorestore
# Total documents in collection: 674
# Successfully added 248 documents to vectorestore
# Total documents in collection: 675
# Successfully added 248 documents to vectorestore
# Total documents in collection: 676
# Successfully added 248 documents to vectorestore
# Total documents in collection: 677
# Successfully added 248 documents to vectorestore
# Total documents in collection: 678
# Successfully added 248 documents to vectorestore
# Total documents in collection: 679
# Successfully added 248 documents to vectorestore
# Total documents in collection: 680
# Successfully added 248 documents to vectorestore
# Total documents in collection: 681
# Successfully added 248 documents to vectorestore
# Total documents in collection: 682
# Successfully added 248 documents to vectorestore
# Total documents in collection: 683
# Successfully added 248 documents to vectorestore
# Total documents in collection: 684
# Successfully added 248 documents to vectorestore
# Total documents in collection: 685
# Successfully added 248 documents to vectorestore
# Total documents in collection: 686
# Successfully added 248 documents to vectorestore
# Total documents in collection: 687
# Successfully added 248 documents to vectorestore
# Total documents in collection: 688
# Successfully added 248 documents to vectorestore
# Total documents in collection: 689
# Successfully added 248 documents to vectorestore
# Total documents in collection: 690
# Successfully added 248 documents to vectorestore
# Total documents in collection: 691
# Successfully added 248 documents to vectorestore
# Total documents in collection: 692
# Successfully added 248 documents to vectorestore
# Total documents in collection: 693
# Successfully added 248 documents to vectorestore
# Total documents in collection: 694
# Successfully added 248 documents to vectorestore
# Total documents in collection: 695
# Successfully added 248 documents to vectorestore
# Total documents in collection: 696
# Successfully added 248 documents to vectorestore
# Total documents in collection: 697
# Successfully added 248 documents to vectorestore
# Total documents in collection: 698
# Successfully added 248 documents to vectorestore
# Total documents in collection: 699
# Successfully added 248 documents to vectorestore
# Total documents in collection: 700
# Successfully added 248 documents to vectorestore
# Total documents in collection: 701
# Successfully added 248 documents to vectorestore
# Total documents in collection: 702
# Successfully added 248 documents to vectorestore
# Total documents in collection: 703
# Successfully added 248 documents to vectorestore
# Total documents in collection: 704
# Successfully added 248 documents to vectorestore
# Total documents in collection: 705
# Successfully added 248 documents to vectorestore
# Total documents in collection: 706
# Successfully added 248 documents to vectorestore
# Total documents in collection: 707
# Successfully added 248 documents to vectorestore
# Total documents in collection: 708
# Successfully added 248 documents to vectorestore
# Total documents in collection: 709
# Successfully added 248 documents to vectorestore
# Total documents in collection: 710
# Successfully added 248 documents to vectorestore
# Total documents in collection: 711
# Successfully added 248 documents to vectorestore
# Total documents in collection: 712
# Successfully added 248 documents to vectorestore
# Total documents in collection: 713
# Successfully added 248 documents to vectorestore
# Total documents in collection: 714
# Successfully added 248 documents to vectorestore
# Total documents in collection: 715
# Successfully added 248 documents to vectorestore
# Total documents in collection: 716
# Successfully added 248 documents to vectorestore
# Total documents in collection: 717
# Successfully added 248 documents to vectorestore
# Total documents in collection: 718
# Successfully added 248 documents to vectorestore
# Total documents in collection: 719
# Successfully added 248 documents to vectorestore
# Total documents in collection: 720
# Successfully added 248 documents to vectorestore
# Total documents in collection: 721
# Successfully added 248 documents to vectorestore
# Total documents in collection: 722
# Successfully added 248 documents to vectorestore
# Total documents in collection: 723
# Successfully added 248 documents to vectorestore
# Total documents in collection: 724
# Successfully added 248 documents to vectorestore
# Total documents in collection: 725
# Successfully added 248 documents to vectorestore
# Total documents in collection: 726
# Successfully added 248 documents to vectorestore
# Total documents in collection: 727
# Successfully added 248 documents to vectorestore
# Total documents in collection: 728
# Successfully added 248 documents to vectorestore
# Total documents in collection: 729
# Successfully added 248 documents to vectorestore
# Total documents in collection: 730
# Successfully added 248 documents to vectorestore
# Total documents in collection: 731
# Successfully added 248 documents to vectorestore
# Total documents in collection: 732
# Successfully added 248 documents to vectorestore
# Total documents in collection: 733
# Successfully added 248 documents to vectorestore
# Total documents in collection: 734
# Successfully added 248 documents to vectorestore
# Total documents in collection: 735
# Successfully added 248 documents to vectorestore
# Total documents in collection: 736
# Successfully added 248 documents to vectorestore
# Total documents in collection: 737
# Successfully added 248 documents to vectorestore
# Total documents in collection: 738
# Successfully added 248 documents to vectorestore
# Total documents in collection: 739
# Successfully added 248 documents to vectorestore
# Total documents in collection: 740
# Successfully added 248 documents to vectorestore
# Total documents in collection: 741
# Successfully added 248 documents to vectorestore
# Total documents in collection: 742
# Successfully added 248 documents to vectorestore
# Total documents in collection: 743
# Successfully added 248 documents to vectorestore
# Total documents in collection: 744

# %% [markdown]
# # Retriever pipeline from VectoreStore

# %%
class RAGretriever:
    """Handles query-based retrieval from the vectorestore"""

    def __init__(self, vector_store: VectorStore, embedding_manager: EmbeddingManager):
        """
        Initialize the retriever

        Args:
            vector_store: Contains embeddings of the documents
            embedding_manager: Manager for generating query embeddings
        """
        self.vector_store = vector_store
        self.embedding_manager = embedding_manager

    def retrieve(self, query: str, top_k: int = 5, score_threshold: float = 0.0) -> List[Dict[str, Any]]:
        """
        Retrieve relevant documents for a query

        Args:
            query: The search query
            top_k: Number of top results to return 
            score_threshold: Minimum similarity score threshold

        Returns:
            List of dictionaries containing retrieved documents and metadata
        """

        print(f"Retrieving following documents for the query: {query}")
        print(f"Top k: {top_k}, Score threshold: {score_threshold}")

        # Generate query embedding

        query_embedding = self.embedding_manager.generate_embeddings([query])[0]

        # Search in vector store  
        try:
            results = self.vector_store.collection.query(    # We pass the query embedding(in the form of a list) to the vector_store and the top_k results
                query_embeddings=[query_embedding.tolist()],
                n_results = top_k
            )
        
            # Processes docs
            retrieved_docs = []

            # Once we get the results there will be an internal key called documents
            # Then we can get the documents info, metadata, distances etc.
            if results['documents'] and results['documents'][0]:
                documents = results['documents'][0]
                metadatas = results['metadatas'][0]
                distances = results['distances'][0]
                ids = results['ids'][0]

                for i, (doc_id, document, metadata, distance) in enumerate(zip(ids, documents, metadatas, distances)):
                    # Convert distance to similarity score (ChromaDB uses cosine distance)
                    similarity_score = 1 - distance

                    if similarity_score >= score_threshold:
                        retrieved_docs.append({
                            'id': doc_id,
                            'content': document,
                            'metadata': metadata,
                            'similarity_score': similarity_score,
                            'distance': distance,
                            'rank': i+1
                        })
                print(f"Retrieved {len(retrieved_docs)} documents (after filtering)")
            else:
                print("Documents not found")

            return retrieved_docs
    
        except Exception as e:
            print(f"Error during retrieval {e}")
            return []

rag_retriever = RAGretriever(vectorstore, embedding_manager)

# %%
rag_retriever

# %%
rag_retriever.retrieve("""MINISTRY OF FLOWGRAMMING
EMERGENCY PROCESSING DIRECTIVE 011
Expedited Approval Protocols for Critical Workflows
CLASSIFICATION: Administrative Urgent
EFFECTIVE: July 1, 2025
SUPERSEDES: All previous emergency protocols
DISTRIBUTION: All reviewing officers, supervisory staff""")
# Out:
# Retrieving following documents for the query: MINISTRY OF FLOWGRAMMING
# EMERGENCY PROCESSING DIRECTIVE 011
# Expedited Approval Protocols for Critical Workflows
# CLASSIFICATION: Administrative Urgent
# EFFECTIVE: July 1, 2025
# SUPERSEDES: All previous emergency protocols
# DISTRIBUTION: All reviewing officers, supervisory staff
# Top k: 5, Score threshold: 0.0
# Generate embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]
# Generated embeddings with shape: {embeddings.shape}
# Retrieved 5 documents (after filtering)
# [{'id': 'doc_c63ab0e5_105',
#   'content': 'MINISTRY OF FLOWGRAMMING \nEMERGENCY PROCESSING DIRECTIVE 011 \nExpedited Approval Protocols for Critical Workflows \nCLASSIFICATION: Administrative Urgent\u200b\n EFFECTIVE: July 1, 2025\u200b\n SUPERSEDES: All previous emergency protocols\u200b\n DISTRIBUTION: All reviewing officers, supervisory staff \n \nSECTION I: EMERGENCY CRITERIA MATRIX \nEmergency processing shall be granted ONLY when applications meet one or more of the \nfollowing critical thresholds: \nTIER 1 - IMMEDIATE THREATS \n●\u200b Active security breach mitigation \n●\u200b Critical infrastructure failure response \n●\u200b Public safety emergency workflows \n●\u200b Regulatory compliance under legal deadline \n●\u200b System failure requiring immediate restoration \nTIER 2 - TIME-CRITICAL OPERATIONS \n●\u200b Vendor system outage affecting business continuity \n●\u200b Financial reporting deadline compliance \n●\u200b Third-party integration failure resolution \n●\u200b Data recovery operations under regulatory timeframe \n●\u200b Client deliverable obligations with contractual penalties',
#   'metadata': {'author': '',
#    'creator': '',
#    'subject': '',
#    'page': 0,
#    'file_path': '../data/pdf/MoF-policy-11.pdf',
#    'modDate': '',
#    'format': 'PDF 1.4',
#    'total_pages': 4,
#    'creationdate': '',
#    'source': '../data/pdf/MoF-policy-11.pdf',
#    'doc_index': 105,
#    'trapped': '',
#    'keywords': '',
#    'content_length': 987,
#    'producer': 'Skia/PDF m141 Google Docs Renderer',
#    'moddate': '',
#    'title': 'MoF Policy 011',
#    'creationDate': ''},
#   'similarity_score': 0.7847018837928772,
#   'distance': 0.2152981162071228,
#   'rank': 1},
#  {'id': 'doc_7bc5d8d1_105',
#   'content': 'MINISTRY OF FLOWGRAMMING \nEMERGENCY PROCESSING DIRECTIVE 011 \nExpedited Approval Protocols for Critical Workflows \nCLASSIFICATION: Administrative Urgent\u200b\n EFFECTIVE: July 1, 2025\u200b\n SUPERSEDES: All previous emergency protocols\u200b\n DISTRIBUTION: All reviewing officers, supervisory staff \n \nSECTION I: EMERGENCY CRITERIA MATRIX \nEmergency processing shall be granted ONLY when applications meet one or more of the \nfollowing critical thresholds: \nTIER 1 - IMMEDIATE THREATS \n●\u200b Active security breach mitigation \n●\u200b Critical infrastructure failure response \n●\u200b Public safety emergency workflows \n●\u200b Regulatory compliance under legal deadline \n●\u200b System failure requiring immediate restoration \nTIER 2 - TIME-CRITICAL OPERATIONS \n●\u200b Vendor system outage affecting business continuity \n●\u200b Financial reporting deadline compliance \n●\u200b Third-party integration failure resolution \n●\u200b Data recovery operations under regulatory timeframe \n●\u200b Client deliverable obligations with contractual penalties',
#   'metadata': {'creationDate': '',
#    'file_path': '../data/pdf/MoF-policy-11.pdf',
#    'keywords': '',
#    'total_pages': 4,
#    'producer': 'Skia/PDF m141 Google Docs Renderer',
#    'title': 'MoF Policy 011',
#    'source': '../data/pdf/MoF-policy-11.pdf',
#    'content_length': 987,
#    'format': 'PDF 1.4',
#    'author': '',
#    'trapped': '',
#    'moddate': '',
#    'creationdate': '',
#    'subject': '',
#    'doc_index': 105,
#    'page': 0,
#    'creator': '',
#    'modDate': ''},
#   'similarity_score': 0.7847018837928772,
#   'distance': 0.2152981162071228,
#   'rank': 2},
#  {'id': 'doc_78b4a903_105',
#   'content': 'MINISTRY OF FLOWGRAMMING \nEMERGENCY PROCESSING DIRECTIVE 011 \nExpedited Approval Protocols for Critical Workflows \nCLASSIFICATION: Administrative Urgent\u200b\n EFFECTIVE: July 1, 2025\u200b\n SUPERSEDES: All previous emergency protocols\u200b\n DISTRIBUTION: All reviewing officers, supervisory staff \n \nSECTION I: EMERGENCY CRITERIA MATRIX \nEmergency processing shall be granted ONLY when applications meet one or more of the \nfollowing critical thresholds: \nTIER 1 - IMMEDIATE THREATS \n●\u200b Active security breach mitigation \n●\u200b Critical infrastructure failure response \n●\u200b Public safety emergency workflows \n●\u200b Regulatory compliance under legal deadline \n●\u200b System failure requiring immediate restoration \nTIER 2 - TIME-CRITICAL OPERATIONS \n●\u200b Vendor system outage affecting business continuity \n●\u200b Financial reporting deadline compliance \n●\u200b Third-party integration failure resolution \n●\u200b Data recovery operations under regulatory timeframe \n●\u200b Client deliverable obligations with contractual penalties',
#   'metadata': {'subject': '',
#    'source': '../data/pdf/MoF-policy-11.pdf',
#    'title': 'MoF Policy 011',
#    'content_length': 987,
#    'author': '',
#    'creationDate': '',
#    'file_path': '../data/pdf/MoF-policy-11.pdf',
#    'total_pages': 4,
#    'creator': '',
#    'keywords': '',
#    'creationdate': '',
#    'trapped': '',
#    'moddate': '',
#    'modDate': '',
#    'format': 'PDF 1.4',
#    'page': 0,
#    'producer': 'Skia/PDF m141 Google Docs Renderer',
#    'doc_index': 105},
#   'similarity_score': 0.7847018837928772,
#   'distance': 0.2152981162071228,
#   'rank': 3},
#  {'id': 'doc_998a4817_185',
#   'content': 'emergency criteria. \n4.2 Expedited Review Process \nLegitimate emergency applications undergo accelerated review with priority officer \nassignment and abbreviated documentation requirements. However, security and \ncompliance standards remain unchanged. Emergency processing fees apply as outlined in \nPolicy 002. Applicants must acknowledge that expedited approval may result in additional \nmonitoring or shortened approval durations. Noise: Some applicants submit expedited \nprocessing fee payment receipts dated from future dates, which demonstrates optimism but \nviolates temporal causality and is not accepted as valid payment. \n4.3 Emergency Trigger Restrictions \nEmergency applications are limited to manual and time-based triggers only. Event-driven \nand webhook triggers are prohibited under emergency processing due to insufficient time for \nproper security validation. Emergency workflows must include automatic termination',
#   'metadata': {'title': 'MoF-policy-03',
#    'modDate': '',
#    'moddate': '',
#    'total_pages': 6,
#    'file_path': '../data/pdf/MoF-policy-03.pdf',
#    'content_length': 932,
#    'creationDate': '',
#    'doc_index': 185,
#    'creator': '',
#    'author': '',
#    'format': 'PDF 1.4',
#    'subject': '',
#    'page': 3,
#    'creationdate': '',
#    'keywords': '',
#    'trapped': '',
#    'source': '../data/pdf/MoF-policy-03.pdf',
#    'producer': 'Skia/PDF m141 Google Docs Renderer'},
#   'similarity_score': 0.3285810947418213,
#   'distance': 0.6714189052581787,
#   'rank': 4},
#  {'id': 'doc_8ce45b48_185',
#   'content': 'emergency criteria. \n4.2 Expedited Review Process \nLegitimate emergency applications undergo accelerated review with priority officer \nassignment and abbreviated documentation requirements. However, security and \ncompliance standards remain unchanged. Emergency processing fees apply as outlined in \nPolicy 002. Applicants must acknowledge that expedited approval may result in additional \nmonitoring or shortened approval durations. Noise: Some applicants submit expedited \nprocessing fee payment receipts dated from future dates, which demonstrates optimism but \nviolates temporal causality and is not accepted as valid payment. \n4.3 Emergency Trigger Restrictions \nEmergency applications are limited to manual and time-based triggers only. Event-driven \nand webhook triggers are prohibited under emergency processing due to insufficient time for \nproper security validation. Emergency workflows must include automatic termination',
#   'metadata': {'modDate': '',
#    'keywords': '',
#    'doc_index': 185,
#    'trapped': '',
#    'file_path': '../data/pdf/MoF-policy-03.pdf',
#    'page': 3,
#    'format': 'PDF 1.4',
#    'title': 'MoF-policy-03',
#    'subject': '',
#    'moddate': '',
#    'total_pages': 6,
#    'author': '',
#    'producer': 'Skia/PDF m141 Google Docs Renderer',
#    'creator': '',
#    'source': '../data/pdf/MoF-policy-03.pdf',
#    'creationDate': '',
#    'creationdate': '',
#    'content_length': 932},
#   'similarity_score': 0.3285810947418213,
#   'distance': 0.6714189052581787,
#   'rank': 5}]

# %% [markdown]
# # Integration VectorDB context pipeline with LLM output

# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key, model_name="llama-3.3-70b-versatile", temperature=0.1, max_tokens=1024)

# Simple RAG function: retrieve context + answer generation
def simple_rag(query, retriever, llm, top_k=3):
    # retrieve the context by passing the query to the embeddingmanager (generating vectors) pass the vectors to the ChromaDB 
    # and ask it to return top_k contexts wrt to our query embedding
    results = retriever.retrieve(query, top_k=top_k)
    context = "\n\n".join([doc["content"] for doc in results]) if results else "" # joining to doc content with double new line
    if not context:
        print("No context found to answer the question")
    
    # generate the answer using the Groq LLM
    prompt = f"""Use the following context to answer the question concisely
        Context: {context}

        Query: {query}

        Answer: """
    
    response=llm.invoke([prompt.format(context=context, query=query)])
    return response.content

# %%
answer = simple_rag("What is detection and investigation procedure in MoF policy: Invalid decisions and Reassignment process?", rag_retriever, llm)
print(answer)
# Out:
# Retrieving following documents for the query: What is detection and investigation procedure in MoF policy: Invalid decisions and Reassignment process?
# Top k: 3, Score threshold: 0.0
# Generate embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  1.84it/s]
# Generated embeddings with shape: {embeddings.shape}
# Retrieved 3 documents (after filtering)
# The provided context does not mention the detection and investigation procedure in MoF Policy 008: Invalid Decisions & Reassignment Process. It only discusses the decision invalidation criteria, including conflict-based invalidation and procedural violation invalidation.

# %% [markdown]
# # Advanced RAG Pipeline

# %%
def advanced_RAG(query, retriever, llm, top_k=3, min_score=0.2, return_context=False):
    """
    RAG pipeline with extra features:
        Returns answer, source, confidence score and optionally full context.
    """
    results = retriever.retrieve(query, top_k=top_k, score_threshold=min_score)
    if not results:
        return {'answer': 'No relevant context found.', 'sources': [], 'confidence': 0.0, 'context': ''}
    
    # Prepare context and sources
    context = "\n\n".join([doc['content'] for doc in results])
    sources=[{
        'source': doc['metadata'].get('source_file', doc['metadata'].get('source', 'unknown')),
        'page': doc['metadata'].get('page', 'unknown'),
        'score': doc['similarity_score'],
        'preview': doc['content'][:300] + '...'
    }for doc in results]

    confidence = max([doc['similarity_score']for doc in results])

    prompt = f"Use the following context to answer the question concisely: \n Context: {context} \n\n Question: {query}" 
    response = llm.invoke([prompt.format(context=context, query=query)])

    output = {
        'answer': response.content,
        'sources': sources,
        'confidence': confidence
    }
    if return_context:
        output['context'] = context
    return output

result = advanced_RAG("What are the audit log requirements?", rag_retriever, llm, top_k=3, min_score=0.1, return_context=True)
print("Answer:", result['answer'])
print("Sources:", result['sources'])
print("Confidence:", result['confidence'])
print("Context preview:", result['context'][:300])
# Out:
# Retrieving following documents for the query: What are the audit log requirements?
# Top k: 3, Score threshold: 0.1
# Generate embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# Generated embeddings with shape: {embeddings.shape}
# Retrieved 3 documents (after filtering)
# Answer: Audit logs must be retained for a minimum of 7 years, with automated backup and redundant storage. Storage protocols include encryption, access control, and integrity verification, and must comply with governmental record-keeping standards and privacy protection regulations.
# Sources: [{'source': '../data/pdf/MoF-policy-10.pdf', 'page': 0, 'score': 0.23504728078842163, 'preview': 'complexity or security classification levels. Noise: System administrators sometimes request \ndetailed performance metrics or creative logging format modifications, which demonstrate \ntechnical interest but must conform to established forensic and legal requirements. \n1.2 Data Retention and Storage ...'}, {'source': '../data/pdf/MoF-policy-10.pdf', 'page': 0, 'score': 0.23504728078842163, 'preview': 'complexity or security classification levels. Noise: System administrators sometimes request \ndetailed performance metrics or creative logging format modifications, which demonstrate \ntechnical interest but must conform to established forensic and legal requirements. \n1.2 Data Retention and Storage ...'}, {'source': '../data/pdf/MoF-policy-10.pdf', 'page': 0, 'score': 0.23504728078842163, 'preview': 'complexity or security classification levels. Noise: System administrators sometimes request \ndetailed performance metrics or creative logging format modifications, which demonstrate \ntechnical interest but must conform to established forensic and legal requirements. \n1.2 Data Retention and Storage ...'}]
# Confidence: 0.23504728078842163
# Context preview: complexity or security classification levels. Noise: System administrators sometimes request
# detailed performance metrics or creative logging format modifications, which demonstrate
# technical interest but must conform to established forensic and legal requirements.
# 1.2 Data Retention and Storage
